# %%
# !pip install -U ultralytics roboflow pyyaml pandas
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.70-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.0 MB/s eta 0:00:00
# Collecting roboflow
#   Downloading roboflow-1.3.10-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting pandas
#   Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.5.20)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.0)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.3 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.3)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (8.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# Downloading ultralytics-8.4.70-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.2 MB/s eta 0:00:00
# Downloading roboflow-1.3.10-py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 27.1 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.1 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.2 MB/s eta 0:00:00
# Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 124.4 MB/s eta 0:00:00
# Downloading pi_heif-1.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 88.6 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 128.0 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, opencv-python-headless, idna, pandas, roboflow, ultralytics-thop, ultralytics
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.18
#     Uninstalling idna-3.18:
#       Successfully uninstalled idna-3.18
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.3 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.3 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.3 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.3 which is incompatible.
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pandas-3.0.3 pi-heif-1.4.0 pillow-avif-plugin-1.5.5 roboflow-1.3.10 ultralytics-8.4.70 ultralytics-thop-2.0.20

# %%
ROBOFLOW_WORKSPACE = "2026-oss"
ROBOFLOW_PROJECT = "ai-picture-book-object-detection"

# Roboflow 최신 통합 데이터셋 버전
ROBOFLOW_VERSION = 11

# 사용할 YOLO 모델과 학습 run 이름
MODEL_NAME = "yolo11n.pt"
RUN_NAME = "picture_book_yolo11n_v11"

# 학습 설정
IMG_SIZE = 640
EPOCHS = 100
BATCH_SIZE = 16
CONF_THRESHOLD = 0.25

# %%
# Colab에서 GPU가 정상적으로 연결되었는지 확인
# !nvidia-smi
# Out:
# Thu Jun 18 09:37:37 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from roboflow import Roboflow
from google.colab import userdata

ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')

rf = Roboflow(api_key=ROBOFLOW_API_KEY)

project = rf.workspace(ROBOFLOW_WORKSPACE).project(ROBOFLOW_PROJECT)

dataset = project.version(ROBOFLOW_VERSION).download("yolov8")

print("Dataset downloaded to:", dataset.location)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 94.0%
# Version export complete for yolov8 format
# Downloading Dataset Version Zip in AI-Picture-Book-Object-Detection-11 to yolov8:: 100%|██████████| 110070/110070 [00:07<00:00, 14439.45it/s]
# Extracting Dataset Version Zip to AI-Picture-Book-Object-Detection-11 in yolov8:: 100%|██████████| 4859/4859 [00:01<00:00, 4508.17it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Dataset downloaded to: /content/AI-Picture-Book-Object-Detection-11

# %%
# data.yaml 파일을 확인하고, 학습 경로를 절대경로로 보정
import os
import yaml

yaml_path = os.path.join(dataset.location, "data.yaml")

print("Original data.yaml path:", yaml_path)

with open(yaml_path, "r", encoding="utf-8") as f:
    data_yaml = yaml.safe_load(f)

print("Original data.yaml:")
print(data_yaml)

# 경로 오류를 줄이기 위해 train/valid/test 이미지 경로를 절대경로로 수정
data_yaml["train"] = os.path.join(dataset.location, "train", "images")
data_yaml["val"] = os.path.join(dataset.location, "valid", "images")
data_yaml["test"] = os.path.join(dataset.location, "test", "images")

with open(yaml_path, "w", encoding="utf-8") as f:
    yaml.safe_dump(data_yaml, f, allow_unicode=True, sort_keys=False)

print("\nUpdated data.yaml:")
with open(yaml_path, "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# Original data.yaml path: /content/AI-Picture-Book-Object-Detection-11/data.yaml
# Original data.yaml:
# {'names': ['book_flower', 'book_flowerpot', 'book_monkey', 'book_stone', 'braille', 'tactile_flower', 'tactile_flowerpot', 'tactile_monkey', 'tactile_stone', 'text'], 'nc': 10, 'roboflow': {'license': 'MIT', 'project': 'ai-picture-book-object-detection', 'url': 'https://universe.roboflow.com/2026-oss/ai-picture-book-object-detection/dataset/11', 'version': 11, 'workspace': '2026-oss'}, 'test': '../test/images', 'train': '../train/images', 'val': '../valid/images'}
#
# Updated data.yaml:
# names:
# - book_flower
# - book_flowerpot
# - book_monkey
# - book_stone
# - braille
# - tactile_flower
# - tactile_flowerpot
# - tactile_monkey
# - tactile_stone
# - text
# nc: 10
# roboflow:
#   license: MIT
#   project: ai-picture-book-object-detection
#   url: https://universe.roboflow.com/2026-oss/ai-picture-book-object-detection/dataset/11
#   version: 11
#   workspace: 2026-oss
# test: /content/AI-Picture-Book-Object-Detection-11/test/images
# train: /content/AI-Picture-Book-Object-Detection-11/train/images
# val: /content/AI-Picture-Book-Object-Detection-11/valid/images

# %%
import yaml

EXPECTED_CLASSES = [
    "book_flower",
    "book_flowerpot",
    "book_monkey",
    "book_stone",
    "braille",
    "tactile_flower",
    "tactile_flowerpot",
    "tactile_monkey",
    "tactile_stone",
    "text"
]

with open(yaml_path, "r", encoding="utf-8") as f:
    data_yaml = yaml.safe_load(f)

names = data_yaml.get("names")

if isinstance(names, dict):
    actual_classes = [names[k] for k in sorted(names.keys(), key=lambda x: int(x))]
else:
    actual_classes = names

print("Actual classes:")
for idx, name in enumerate(actual_classes):
    print(f"{idx}: {name}")

print("\nExpected class count:", len(EXPECTED_CLASSES))
print("Actual class count:", len(actual_classes))

missing_classes = sorted(set(EXPECTED_CLASSES) - set(actual_classes))
extra_classes = sorted(set(actual_classes) - set(EXPECTED_CLASSES))

print("\nMissing classes:", missing_classes)
print("Extra classes:", extra_classes)

assert len(actual_classes) == len(EXPECTED_CLASSES), "클래스 개수가 예상과 다릅니다."
assert set(actual_classes) == set(EXPECTED_CLASSES), "클래스 목록이 예상과 다릅니다."

print("\n클래스 검증 완료: 데이터셋에 10개 클래스가 모두 포함되어 있습니다.")
# Out:
# Actual classes:
# 0: book_flower
# 1: book_flowerpot
# 2: book_monkey
# 3: book_stone
# 4: braille
# 5: tactile_flower
# 6: tactile_flowerpot
# 7: tactile_monkey
# 8: tactile_stone
# 9: text
#
# Expected class count: 10
# Actual class count: 10
#
# Missing classes: []
# Extra classes: []
#
# 클래스 검증 완료: 데이터셋에 10개 클래스가 모두 포함되어 있습니다.

# %%
# train, valid, test 데이터가 정상적으로 나뉘어 있는지 확인
import glob

for split in ["train", "valid", "test"]:
    image_dir = os.path.join(dataset.location, split, "images")
    label_dir = os.path.join(dataset.location, split, "labels")

    image_count = len(glob.glob(os.path.join(image_dir, "*")))
    label_count = len(glob.glob(os.path.join(label_dir, "*")))

    print(f"{split}: images={image_count}, labels={label_count}")
# Out:
# train: images=2124, labels=2124
# valid: images=202, labels=202
# test: images=101, labels=101

# %%
# YOLO11n 모델을 불러와 v11 데이터셋으로 학습
from ultralytics import YOLO

model = YOLO(MODEL_NAME)

train_results = model.train(
    data=yaml_path,
    imgsz=IMG_SIZE,
    epochs=EPOCHS,
    batch=BATCH_SIZE,
    name=RUN_NAME,
    project="runs/detect"
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 229.7MB/s 0.0s
# Ultralytics 8.4.70 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/AI-Picture-Book-Object-Detection-11/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name
🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,584,102 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.1it/s 3.3s
#                    all        202        226       0.91       0.86      0.919      0.719
#            book_flower         14         14      0.974      0.786      0.931      0.523
#         book_flowerpot         20         20      0.835        0.8      0.887       0.66
#            book_monkey         29         29      0.859      0.793      0.903      0.709
#             book_stone         13         13      0.793          1      0.986      0.863
#                braille         34         34          1      0.931      0.994      0.849
#         tactile_flower         20         25      0.923       0.76       0.82      0.637
#      tactile_flowerpot         21         31      0.922      0.766      0.853      0.695
#         tactile_monkey         19         20      0.855        0.9      0.891      0.706
#          tactile_stone         11         11      0.964          1      0.995       0.86
#                   text         29         29      0.978      0.862      0.936      0.691
# Speed: 0.2ms preprocess, 2.7ms inference, 0.0ms loss, 5.1ms postprocess per image
# Results saved to /content/runs/detect/runs/detect/picture_book_yolo11n_v11

# %%
# YOLO11n v6 학습 결과의 best.pt 경로 확인
from pathlib import Path

best_weights = [
    path for path in Path("/content").rglob("best.pt")
    if RUN_NAME in str(path)
]

best_weights = sorted(best_weights)

print("best.pt files:")
for path in best_weights:
    print(path)

assert len(best_weights) > 0, "YOLO11n v11 best.pt 파일을 찾지 못했습니다."

best_model_path = str(best_weights[-1])

print("\nBest model path:", best_model_path)
# Out:
# best.pt files:
# /content/runs/detect/runs/detect/picture_book_yolo11n_v11/weights/best.pt
#
# Best model path: /content/runs/detect/runs/detect/picture_book_yolo11n_v11/weights/best.pt

# %%
# best.pt 모델을 test set 기준으로 평가
best_model = YOLO(best_model_path)

metrics = best_model.val(
    data=yaml_path,
    split="test",
    imgsz=IMG_SIZE
)
# Out:
# Ultralytics 8.4.70 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,584,102 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 939.9±204.1 MB/s, size: 39.0 KB)
# val: Scanning /content/AI-Picture-Book-Object-Detection-11/test/labels... 101 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 101/101 1.8Kit/s 0.1s
# val: New cache created: /content/AI-Picture-Book-Object-Detection-11/test/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 43, len(boxes) = 109. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        101        109      0.903      0.857      0.919      0.708
#            book_flower          5          5      0.931          1      0.995      0.561
#         book_flowerpot         13         13      0.927      0.976      0.974      0.686
#            book_monkey         11         11          1      0.813      0.968      0.752
#             book_stone          5          5          1      0.866      0.995       0.86
#                braille         15         15       0.79      0.867      0.863      0.715
#         tactile_flower          7          7      0.783      0.857      0.855      0.648
#      tactile_flowerpot         10         12      0.818      0.751      0.815      0.689
#         tactile_monkey         10         11       0.91      0.636      0.843      0.626
#          tactile_stone          5          5      0.936          1      0.995      0.845
#                   text         25         25      0.933        0.8      0.882      0.695
# Speed: 4.5ms preprocess, 7.6ms inference, 0.0ms loss, 2.5ms postprocess per image
# Results saved to /content/runs/detect/val

# %%
# 전체 성능 지표 정리
summary = {
    "model": MODEL_NAME,
    "dataset_version": ROBOFLOW_VERSION,
    "precision": float(metrics.box.mp),
    "recall": float(metrics.box.mr),
    "mAP@0.5": float(metrics.box.map50),
    "mAP@0.5:0.95": float(metrics.box.map),
    "best_model_path": best_model_path,
}

summary
# Out:
# {'model': 'yolo11n.pt',
#  'dataset_version': 11,
#  'precision': 0.902700647833157,
#  'recall': 0.8565492313351128,
#  'mAP@0.5': 0.9185599817671213,
#  'mAP@0.5:0.95': 0.7077338832871533,
#  'best_model_path': '/content/runs/detect/runs/detect/picture_book_yolo11n_v11/weights/best.pt'}

# %%
# 클래스별 mAP 성능 확인
import pandas as pd

class_result_rows = []

ap50_values = getattr(metrics.box, "ap50", None)
ap_values = getattr(metrics.box, "ap", None)

for idx, class_name in enumerate(actual_classes):
    row = {
        "class_id": idx,
        "class_name": class_name,
        "mAP@0.5": float(ap50_values[idx]) if ap50_values is not None and idx < len(ap50_values) else None,
        "mAP@0.5:0.95": float(ap_values[idx]) if ap_values is not None and idx < len(ap_values) else None,
    }
    class_result_rows.append(row)

class_results_df = pd.DataFrame(class_result_rows)
class_results_df
# Out:
#    class_id         class_name   mAP@0.5  mAP@0.5:0.95
# 0         0        book_flower  0.995000      0.560758
# 1         1     book_flowerpot  0.973571      0.686055
# 2         2        book_monkey  0.967532      0.752292
# 3         3         book_stone  0.995000      0.859600
# 4         4            braille  0.863248      0.715065
# 5         5     tactile_flower  0.855000      0.648417
# 6         6  tactile_flowerpot  0.815438      0.689175
# 7         7     tactile_monkey  0.843319      0.626036
# 8         8      tactile_stone  0.995000      0.845000
# 9         9               text  0.882491      0.694942

# %%
# 평가 결과를 JSON, CSV 파일로 저장
import json

os.makedirs("results", exist_ok=True)

summary_path = "results/yolo11n_v11_summary.json"
class_result_path = "results/yolo11n_v11_class_results.csv"

with open(summary_path, "w", encoding="utf-8") as f:
    json.dump(summary, f, ensure_ascii=False, indent=2)

class_results_df.to_csv(class_result_path, index=False, encoding="utf-8-sig")

print("Saved summary:", summary_path)
print("Saved class results:", class_result_path)
# Out:
# Saved summary: results/yolo11n_v11_summary.json
# Saved class results: results/yolo11n_v11_class_results.csv

# %%
# test 이미지에 대해 실제 예측 결과 저장
test_image_path = os.path.join(dataset.location, "test", "images")

predict_results = best_model.predict(
    source=test_image_path,
    conf=CONF_THRESHOLD,
    save=True,
    name=f"{RUN_NAME}_test_predictions"
)
# Out:
# image 1/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flower_0008_jpg.rf.037ec5b92fb2d319e72bd8191f9e8872.jpg: 640x640 1 book_flower, 8.2ms
# image 2/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flower_0016_jpg.rf.12d96b64cedcd601f418c06464bb1354.jpg: 640x640 1 book_flower, 8.3ms
# image 3/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flower_0025_jpg.rf.0f6b58ae1771eb924e55e84e2d9d1154.jpg: 640x640 1 book_flower, 8.0ms
# image 4/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flower_0034_jpg.rf.6ace9c1d397ab45f27851cadfcd054d6.jpg: 640x640 1 book_flower, 7.8ms
# image 5/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flower_0038_jpg.rf.eee736803a2d92309159376e8a1fb624.jpg: 640x640 1 book_flower, 7.9ms
# image 6/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flowerpot_0007_jpg.rf.b7d817eac7c7e7c1f07ed68a4903f058.jpg: 640x640 1 book_flowerpot, 7.8ms
# image 7/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flowerpot_0009_jpeg.rf.a164be51465053afaca7d4e779734464.jpg: 640x640 1 book_flowerpot, 1 braille, 1 text, 7.8ms
# image 8/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flowerpot_0027_jpg.rf.c611347a8538bb4911db9ace75ecaace.jpg: 640x640 1 book_flowerpot, 1 book_monkey, 7.9ms
# image 9/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flowerpot_0041_jpeg.rf.c020f3605f3516eb92fe4c6c38252c56.jpg: 640x640 1 book_flowerpot, 7.9ms
# image 10/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flowerpot_0044_jpeg.rf.8860902f5049afc9d4a453132d2e8cf7.jpg: 640x640 1 book_flowerpot, 8.4ms
# image 11/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flowerpot_0059_JPEG.rf.5b8d7c84cdfea6c0b91c21bc63728279.jpg: 640x640 1 book_flowerpot, 8.8ms
# image 12/101 /content/AI-Picture-Book-Object-Detection-11/test/images/book_flowerpot_
101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_00010_jpg.rf.51b7a137efd9b1b4f056bf55a858ae67.jpg: 640x640 1 text, 8.6ms
# image 81/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0014_jpg.rf.86a8ff4a1529bfc1faab582c3167b298.jpg: 640x640 1 text, 8.0ms
# image 82/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0042_jpg.rf.56fd00b464a3231dbbae0c49b74d97eb.jpg: 640x640 1 text, 7.4ms
# image 83/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0047_jpg.rf.1a0916343f44aaea5a8c8062578b2eb8.jpg: 640x640 1 text, 7.8ms
# image 84/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0048_jpg.rf.3db7dc0a3840832e8af2255e0064756d.jpg: 640x640 1 text, 10.7ms
# image 85/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0050_jpg.rf.8c5b9cf26dedd1c548845f65c65dd856.jpg: 640x640 1 text, 8.4ms
# image 86/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0055_jpg.rf.8384b73258bed9f15852261dcdbb4491.jpg: 640x640 1 text, 8.0ms
# image 87/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0068_jpg.rf.21925a0b0220e889d524c080d1ebc7ca.jpg: 640x640 1 text, 7.3ms
# image 88/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0069_jpg.rf.787d9605f8686acc972d9317c87f67ca.jpg: 640x640 1 text, 7.6ms
# image 89/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0070_jpg.rf.0e230c8050bc3e221b577b4f20334f26.jpg: 640x640 1 tactile_flower, 1 tactile_monkey, 9.3ms
# image 90/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0071_jpg.rf.d6ab2a723f08b62cf1c735657c501027.jpg: 640x640 1 text, 7.5ms
# image 91/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0074_jpg.rf.0dd649f33241c47fd39505a1dc5af7af.jpg: 640x640 1 text, 7.7ms
# image 92/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0076_jpg.rf.1afc7226192fb99b037d2414ab0c5cd8.jpg: 640x640 1 text, 7.6ms
# image 93/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0117_jpg.rf.6f7f7fa213a204dd2ac77f4d5e6f6108.jpg: 640x640 1 text, 7.3ms
# image 94/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0129_jpg.rf.4f2b420e438f65bbe2debfd7b30c9b39.jpg: 640x640 1 text, 8.5ms
# image 95/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0163_jpg.rf.51bd9ab0a31bc60d1591bafcb52f86a2.jpg: 640x640 1 text, 7.8ms
# image 96/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0166_jpg.rf.0a906724c54cf5ead5d0fbb80bfb2ea7.jpg: 640x640 1 text, 7.6ms
# image 97/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0175_jpg.rf.853bd2baf7663319a18f6170d08ae07e.jpg: 640x640 1 book_stone, 7.2ms
# image 98/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0182_jpg.rf.1406e64f39869e9f991a5b12979f4475.jpg: 640x640 1 text, 9.1ms
# image 99/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0185_jpg.rf.23c3735754f08a12bbba4e3da5feb384.jpg: 640x640 1 text, 9.3ms
# image 100/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0195_jpg.rf.0eda9c2c8c1291ed86f0ef56e5cdd669.jpg: 640x640 1 text, 7.8ms
# image 101/101 /content/AI-Picture-Book-Object-Detection-11/test/images/text_0206_jpg.rf.51b5f9115d28381b4fbfc0e5beeac318.jpg: 640x640 1 text, 7.5ms
# Speed: 1.5ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/picture_book_yolo11n_v11_test_predictions

# %%
# 저장된 예측 결과 이미지 일부 확인
from IPython.display import Image, display

result_images = sorted(glob.glob(f"runs/detect/{RUN_NAME}_test_predictions*/*.jpg"))

print("Detected images:", len(result_images))

for img_path in result_images[:10]:
    display(Image(filename=img_path))
# Out:
# Detected images: 101

# %%
# 백엔드 연동 시 필요한 모델 정보 정리
model_info = {
    "model_name": MODEL_NAME,
    "run_name": RUN_NAME,
    "dataset_version": ROBOFLOW_VERSION,
    "input": {
        "type": "image_or_webcam_frame",
        "image_size": IMG_SIZE,
    },
    "output": {
        "class_name": "detected object class",
        "confidence": "detection confidence score",
        "bbox": "[x1, y1, x2, y2]",
    },
    "classes": actual_classes,
    "best_model_path": best_model_path,
    "metrics": summary,
}

model_info_path = "results/yolo11n_v11_model_info.json"

with open(model_info_path, "w", encoding="utf-8") as f:
    json.dump(model_info, f, ensure_ascii=False, indent=2)

print("Saved model info:", model_info_path)
model_info
# Out:
# Saved model info: results/yolo11n_v11_model_info.json
# {'model_name': 'yolo11n.pt',
#  'run_name': 'picture_book_yolo11n_v11',
#  'dataset_version': 11,
#  'input': {'type': 'image_or_webcam_frame', 'image_size': 640},
#  'output': {'class_name': 'detected object class',
#   'confidence': 'detection confidence score',
#   'bbox': '[x1, y1, x2, y2]'},
#  'classes': ['book_flower',
#   'book_flowerpot',
#   'book_monkey',
#   'book_stone',
#   'braille',
#   'tactile_flower',
#   'tactile_flowerpot',
#   'tactile_monkey',
#   'tactile_stone',
#   'text'],
#  'best_model_path': '/content/runs/detect/runs/detect/picture_book_yolo11n_v11/weights/best.pt',
#  'metrics': {'model': 'yolo11n.pt',
#   'dataset_version': 11,
#   'precision': 0.902700647833157,
#   'recall': 0.8565492313351128,
#   'mAP@0.5': 0.9185599817671213,
#   'mAP@0.5:0.95': 0.7077338832871533,
#   'best_model_path': '/content/runs/detect/runs/detect/picture_book_yolo11n_v11/weights/best.pt'}}

# %% [markdown]
# ## YOLOv5s baseline vs YOLO11n v10 성능 비교
#
# | Model   | Dataset     | Precision | Recall | mAP@0.5 | mAP@0.5:0.95 | 비고                  |
# | ------- | ----------- | --------: | -----: | ------: | -----------: | ------------------- |
# | YOLOv5s | Roboflow v2 |     0.847 |  0.889 |   0.898 |        0.641 | 예인님 테스트 기준 baseline |
# | YOLO11n | Roboflow v10 |     0.835 |  0.719 |   0.776 |        0.545 | 전체 통합 데이터셋 기준       |
#
# ### 결과 해석
#
# YOLO11n은 Roboflow v10 전체 통합 데이터셋을 기준으로 학습 및 평가하였다.
# YOLOv5s baseline은 Roboflow v2 기준 결과이므로, 두 결과는 데이터셋 버전이 달라 직접적인 성능 우열 비교보다는 참고용 비교로 해석한다.
#
# YOLO11n v6의 test set 기준 전체 성능은 Precision 0.835, Recall 0.719, mAP@0.5 0.776, mAP@0.5:0.95 0.545로 확인되었다.
#
# ### 확인 사항
#
# * Roboflow v10 데이터셋에 10개 클래스가 모두 포함되어 있는지 확인함.
# * YOLO11n 학습 후 `best.pt` 파일 경로를 정리함.
# * test set 기준 Precision, Recall, mAP@0.5, mAP@0.5:0.95를 확인함.
# * 예측 결과 이미지를 저장하여 실제 탐지 품질을 확인할 예정임.
# * 백엔드 연동을 위해 class name, confidence, bbox 출력 형식을 정리할 예정임.
