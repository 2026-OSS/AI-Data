# %%
# !pip install -U ultralytics roboflow pyyaml pandas
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.4.68)
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.3.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (3.0.3)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.26.0+cu128)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.5.20)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.0)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.3)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (8.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.29.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.8.0->ultralytics) (1.5.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)

# %%
# =========================
# Project Config
# =========================
# Roboflow 프로젝트 정보
ROBOFLOW_WORKSPACE = "2026-oss"
ROBOFLOW_PROJECT = "ai-picture-book-object-detection"

# Roboflow 최신 통합 데이터셋 버전
ROBOFLOW_VERSION = 6

# 사용할 YOLO 모델과 학습 run 이름
MODEL_NAME = "yolo11n.pt"
RUN_NAME = "picture_book_yolo11n_v6"

# 학습 설정
IMG_SIZE = 640
EPOCHS = 100
BATCH_SIZE = 16
CONF_THRESHOLD = 0.25

# %%
# Colab에서 GPU가 정상적으로 연결되었는지 확인
# !nvidia-smi
# Out:
# Tue Jun 16 10:18:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Roboflow에서 v3 데이터셋 다운로드
from roboflow import Roboflow

rf = Roboflow(api_key=ROBOFLOW_API_KEY)

project = rf.workspace(ROBOFLOW_WORKSPACE).project(ROBOFLOW_PROJECT)

# "yolov8"은 모델명이 아니라 데이터셋 export format임
# 실제 학습 모델은 아래에서 YOLO("yolo11n.pt")로 지정함
dataset = project.version(6).download("yolov8")

print("Dataset downloaded to:", dataset.location)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 94.0%
# Version export complete for yolov8 format
# Downloading Dataset Version Zip in AI-Picture-Book-Object-Detection-6 to yolov8:: 100%|██████████| 103883/103883 [00:01<00:00, 75111.87it/s]
# Extracting Dataset Version Zip to AI-Picture-Book-Object-Detection-6 in yolov8:: 100%|██████████| 4627/4627 [00:00<00:00, 5230.94it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Dataset downloaded to: /content/AI-Picture-Book-Object-Detection-6

# %%
# Roboflow API Key를 Colab Secrets에서 불러오고, 없으면 직접 입력받음
from getpass import getpass

try:
    from google.colab import userdata
    ROBOFLOW_API_KEY = userdata.get("ROBOFLOW_API_KEY")
except Exception:
    ROBOFLOW_API_KEY = None

if not ROBOFLOW_API_KEY:
    ROBOFLOW_API_KEY = getpass("Roboflow API Key를 입력하세요: ")

# 앞뒤 공백 제거
ROBOFLOW_API_KEY = ROBOFLOW_API_KEY.strip()

print("Roboflow API Key loaded:", ROBOFLOW_API_KEY is not None and len(ROBOFLOW_API_KEY) > 0)
print("API Key length:", len(ROBOFLOW_API_KEY))
# Out:
# Roboflow API Key를 입력하세요: ··········
# Roboflow API Key loaded: True
# API Key length: 20

# %%
# data.yaml 파일을 확인하고, 학습 경로를 절대경로로 보정
import os
import yaml

yaml_path = os.path.join(dataset.location, "data.yaml")

print("Original data.yaml path:", yaml_path)

with open(yaml_path, "r", encoding="utf-8") as f:
    data_yaml = yaml.safe_load(f)

print("Original data.yaml:")
print(data_yaml)

# 경로 오류를 줄이기 위해 train/valid/test 이미지 경로를 절대경로로 수정
data_yaml["train"] = os.path.join(dataset.location, "train", "images")
data_yaml["val"] = os.path.join(dataset.location, "valid", "images")
data_yaml["test"] = os.path.join(dataset.location, "test", "images")

with open(yaml_path, "w", encoding="utf-8") as f:
    yaml.safe_dump(data_yaml, f, allow_unicode=True, sort_keys=False)

print("\nUpdated data.yaml:")
with open(yaml_path, "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# Original data.yaml path: /content/AI-Picture-Book-Object-Detection-6/data.yaml
# Original data.yaml:
# {'names': ['book_flower', 'book_flowerpot', 'book_monkey', 'book_stone', 'braille', 'tactile_flower', 'tactile_flowerpot', 'tactile_monkey', 'tactile_stone', 'text'], 'nc': 10, 'roboflow': {'license': 'MIT', 'project': 'ai-picture-book-object-detection', 'url': 'https://universe.roboflow.com/2026-oss/ai-picture-book-object-detection/dataset/6', 'version': 6, 'workspace': '2026-oss'}, 'test': '../test/images', 'train': '../train/images', 'val': '../valid/images'}
#
# Updated data.yaml:
# names:
# - book_flower
# - book_flowerpot
# - book_monkey
# - book_stone
# - braille
# - tactile_flower
# - tactile_flowerpot
# - tactile_monkey
# - tactile_stone
# - text
# nc: 10
# roboflow:
#   license: MIT
#   project: ai-picture-book-object-detection
#   url: https://universe.roboflow.com/2026-oss/ai-picture-book-object-detection/dataset/6
#   version: 6
#   workspace: 2026-oss
# test: /content/AI-Picture-Book-Object-Detection-6/test/images
# train: /content/AI-Picture-Book-Object-Detection-6/train/images
# val: /content/AI-Picture-Book-Object-Detection-6/valid/images

# %%
# v3 데이터셋에 10개 클래스가 모두 포함되어 있는지 확인
with open(yaml_path, "r", encoding="utf-8") as f:
    data_yaml = yaml.safe_load(f)

names = data_yaml.get("names")

# names가 dict 또는 list 형태일 수 있으므로 둘 다 처리
if isinstance(names, dict):
    actual_classes = [names[k] for k in sorted(names.keys(), key=lambda x: int(x))]
else:
    actual_classes = names

print("Actual classes:")
for idx, name in enumerate(actual_classes):
    print(f"{idx}: {name}")

print("\nExpected class count:", len(EXPECTED_CLASSES))
print("Actual class count:", len(actual_classes))

missing_classes = sorted(set(EXPECTED_CLASSES) - set(actual_classes))
extra_classes = sorted(set(actual_classes) - set(EXPECTED_CLASSES))

print("\nMissing classes:", missing_classes)
print("Extra classes:", extra_classes)

assert len(actual_classes) == len(EXPECTED_CLASSES), "클래스 개수가 예상과 다릅니다."
assert set(actual_classes) == set(EXPECTED_CLASSES), "클래스 목록이 예상과 다릅니다."

print("\n클래스 검증 완료: v3 데이터셋에 10개 클래스가 모두 포함되어 있습니다.")
# Out:
# Actual classes:
# 0: book_flower
# 1: book_flowerpot
# 2: book_monkey
# 3: book_stone
# 4: braille
# 5: tactile_flower
# 6: tactile_flowerpot
# 7: tactile_monkey
# 8: tactile_stone
# 9: text
#
# Expected class count: 10
# Actual class count: 10
#
# Missing classes: []
# Extra classes: []
#
# 클래스 검증 완료: v3 데이터셋에 10개 클래스가 모두 포함되어 있습니다.

# %%
# train, valid, test 데이터가 정상적으로 나뉘어 있는지 확인
import glob

for split in ["train", "valid", "test"]:
    image_dir = os.path.join(dataset.location, split, "images")
    label_dir = os.path.join(dataset.location, split, "labels")

    image_count = len(glob.glob(os.path.join(image_dir, "*")))
    label_count = len(glob.glob(os.path.join(label_dir, "*")))

    print(f"{split}: images={image_count}, labels={label_count}")
# Out:
# train: images=2022, labels=2022
# valid: images=193, labels=193
# test: images=96, labels=96

# %%
# YOLO11n 모델을 불러와 v3 데이터셋으로 학습
from ultralytics import YOLO

model = YOLO(MODEL_NAME)

train_results = model.train(
    data=yaml_path,
    imgsz=IMG_SIZE,
    epochs=EPOCHS,
    batch=BATCH_SIZE,
    name=RUN_NAME,
    project="runs/detect"
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB
0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.84G      0.508     0.3511     0.9075          7        640: 100% ━━━━━━━━━━━━ 127/127 3.8it/s 33.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.8it/s 1.4s
#                    all        193        253      0.866      0.853       0.87      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.84G     0.5105     0.3533     0.9127          8        640: 100% ━━━━━━━━━━━━ 127/127 3.7it/s 34.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 3.6it/s 1.9s
#                    all        193        253      0.891      0.824      0.868      0.676
#
# 100 epochs completed in 1.048 hours.
# Optimizer stripped from /content/runs/detect/runs/detect/picture_book_yolo11n_v6/weights/last.pt, 5.5MB
# Optimizer stripped from /content/runs/detect/runs/detect/picture_book_yolo11n_v6/weights/best.pt, 5.5MB
#
# Validating /content/runs/detect/runs/detect/picture_book_yolo11n_v6/weights/best.pt...
# Ultralytics 8.4.68 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,584,102 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.9it/s 3.6s
#                    all        193        253      0.893      0.853       0.88      0.686
#            book_flower         12         12      0.984          1      0.995      0.672
#         book_flowerpot         15         29      0.733      0.793       0.78      0.575
#            book_monkey         36         48      0.896      0.854      0.902      0.775
#             book_stone         13         16      0.868      0.823      0.918      0.653
#                braille         49         49      0.917      0.901      0.908      0.773
#         tactile_flower         14         19      0.955      0.842      0.885      0.718
#      tactile_flowerpot         22         34      0.886      0.824      0.869       0.66
#         tactile_monkey         15         17      0.934      0.837       0.87      0.643
#          tactile_stone         13         13      0.963      0.923      0.925       0.82
#                   text         16         16      0.797      0.737      0.753      0.576
# Speed: 0.3ms preprocess, 2.7ms inference, 0.0ms loss, 5.4ms postprocess per image
# Results saved to /content/runs/detect/runs/detect/picture_book_yolo11n_v6

# %%
# YOLO11n v6 학습 결과의 best.pt 경로 확인
from pathlib import Path

best_weights = [
    path for path in Path("/content").rglob("best.pt")
    if RUN_NAME in str(path)
]

best_weights = sorted(best_weights)

print("best.pt files:")
for path in best_weights:
    print(path)

assert len(best_weights) > 0, "YOLO11n v6 best.pt 파일을 찾지 못했습니다."

best_model_path = str(best_weights[-1])

print("\nBest model path:", best_model_path)
# Out:
# best.pt files:
# /content/runs/detect/runs/detect/picture_book_yolo11n_v6/weights/best.pt
#
# Best model path: /content/runs/detect/runs/detect/picture_book_yolo11n_v6/weights/best.pt

# %%
# best.pt 모델을 test set 기준으로 평가
best_model = YOLO(best_model_path)

metrics = best_model.val(
    data=yaml_path,
    split="test",
    imgsz=IMG_SIZE
)
# Out:
# Ultralytics 8.4.68 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n summary (fused): 101 layers, 2,584,102 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1298.8±460.8 MB/s, size: 36.5 KB)
# val: Scanning /content/AI-Picture-Book-Object-Detection-6/test/labels... 96 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 96/96 2.0Kit/s 0.0s
# val: New cache created: /content/AI-Picture-Book-Object-Detection-6/test/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 72, len(boxes) = 129. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 1.9it/s 3.2s
#                    all         96        129      0.835      0.719      0.776      0.545
#            book_flower         11         11          1      0.937      0.995      0.539
#         book_flowerpot         12         18      0.855      0.778      0.771      0.495
#            book_monkey         14         21      0.718      0.729      0.746      0.488
#             book_stone          9         14      0.836      0.365      0.678      0.342
#                braille         21         22      0.934      0.864      0.913      0.758
#         tactile_flower          4          4      0.597        0.5      0.495       0.42
#      tactile_flowerpot         10         11      0.704      0.727      0.808      0.644
#         tactile_monkey          9         10          1      0.717      0.795      0.611
#          tactile_stone          5          5      0.934        0.8      0.795      0.705
#                   text         12         13       0.77      0.775      0.759       0.45
# Speed: 6.9ms preprocess, 6.7ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to /content/runs/detect/val

# %%
# 전체 성능 지표 정리
summary = {
    "model": MODEL_NAME,
    "dataset_version": ROBOFLOW_VERSION,
    "precision": float(metrics.box.mp),
    "recall": float(metrics.box.mr),
    "mAP@0.5": float(metrics.box.map50),
    "mAP@0.5:0.95": float(metrics.box.map),
    "best_model_path": best_model_path,
}

summary
# Out:
# {'model': 'yolo11n.pt',
#  'dataset_version': 6,
#  'precision': 0.834799931982832,
#  'recall': 0.7191307808985743,
#  'mAP@0.5': 0.7755055488769996,
#  'mAP@0.5:0.95': 0.5451876168317076,
#  'best_model_path': '/content/runs/detect/runs/detect/picture_book_yolo11n_v6/weights/best.pt'}

# %%
# 클래스별 mAP 성능 확인
import pandas as pd

class_result_rows = []

ap50_values = getattr(metrics.box, "ap50", None)
ap_values = getattr(metrics.box, "ap", None)

for idx, class_name in enumerate(actual_classes):
    row = {
        "class_id": idx,
        "class_name": class_name,
        "mAP@0.5": float(ap50_values[idx]) if ap50_values is not None and idx < len(ap50_values) else None,
        "mAP@0.5:0.95": float(ap_values[idx]) if ap_values is not None and idx < len(ap_values) else None,
    }
    class_result_rows.append(row)

class_results_df = pd.DataFrame(class_result_rows)
class_results_df
# Out:
#    class_id         class_name   mAP@0.5  mAP@0.5:0.95
# 0         0        book_flower  0.995000      0.538632
# 1         1     book_flowerpot  0.770906      0.495057
# 2         2        book_monkey  0.745608      0.488197
# 3         3         book_stone  0.677998      0.341839
# 4         4            braille  0.913333      0.758030
# 5         5     tactile_flower  0.495000      0.420000
# 6         6  tactile_flowerpot  0.808353      0.643631
# 7         7     tactile_monkey  0.795000      0.611250
# 8         8      tactile_stone  0.795000      0.705000
# 9         9               text  0.758857      0.450240

# %%
# 평가 결과를 JSON, CSV 파일로 저장
import json

os.makedirs("results", exist_ok=True)

summary_path = "results/yolo11n_v3_summary.json"
class_result_path = "results/yolo11n_v3_class_results.csv"

with open(summary_path, "w", encoding="utf-8") as f:
    json.dump(summary, f, ensure_ascii=False, indent=2)

class_results_df.to_csv(class_result_path, index=False, encoding="utf-8-sig")

print("Saved summary:", summary_path)
print("Saved class results:", class_result_path)
# Out:
# Saved summary: results/yolo11n_v3_summary.json
# Saved class results: results/yolo11n_v3_class_results.csv

# %%
# test 이미지에 대해 실제 예측 결과 저장
test_image_path = os.path.join(dataset.location, "test", "images")

predict_results = best_model.predict(
    source=test_image_path,
    conf=CONF_THRESHOLD,
    save=True,
    name=f"{RUN_NAME}_test_predictions"
)
# Out:
# image 1/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flower_0005_jpg.rf.5fe07f320c974103889f298183a6c0f0.jpg: 640x640 1 book_flower, 7.9ms
# image 2/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flower_0008_jpg.rf.037ec5b92fb2d319e72bd8191f9e8872.jpg: 640x640 1 book_flower, 8.0ms
# image 3/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flower_0021_jpg.rf.149cbb0b26f4a525d1414f5aee65b439.jpg: 640x640 1 book_flower, 9.4ms
# image 4/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flower_0022_jpg.rf.e14732a964c2db2ed3c740a52ace48a0.jpg: 640x640 1 book_flower, 7.9ms
# image 5/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flower_0023_jpg.rf.9d6feadc735893ed5778f65323143dc6.jpg: 640x640 1 book_flower, 7.9ms
# image 6/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flower_0031_jpg.rf.9285ce48d1e7d4dbffc655048bdee7f2.jpg: 640x640 1 book_flower, 7.8ms
# image 7/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flower_0032_jpg.rf.9fbee3ef307d98ad36fe47b956afb265.jpg: 640x640 1 book_flower, 7.8ms
# image 8/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flower_0037_jpg.rf.564166e7e336552e4eb3eb9b2c091637.jpg: 640x640 1 book_flower, 7.8ms
# image 9/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flower_0038_jpg.rf.1ce0ab33b06143a7bc883d12fc13a4d4.jpg: 640x640 1 book_flower, 7.8ms
# image 10/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flower_0039_jpg.rf.b73693bf1d686e0ba8ca9d18f6be297f.jpg: 640x640 1 book_flower, 7.8ms
# image 11/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0001_jpeg.rf.bd70f4fbdee01021e3ae1d7a7ecc9374.jpg: 640x640 1 book_flowerpot, 7.8ms
# image 12/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0009_jpeg.rf.a164be51465053afaca7d4e779734464.jpg: 640x640 1 book_flowerpot, 7.8ms
# image 13/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0021_jpeg.rf.0b4d9ef59fea4a10b1c0d8415bbab59e.jpg: 640x640 1 book_flowerpot, 8.6ms
# image 14/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0028_jpeg.rf.e280d8eb59dc42d7d083cab9f361a766.jpg: 640x640 1 text, 7.8ms
# image 15/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0041_jpeg.rf.c020f3605f3516eb92fe4c6c38252c56.jpg: 640x640 1 book_flowerpot, 7.5ms
# image 16/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0044_jpeg.rf.8860902f5049afc9d4a453132d2e8cf7.jpg: 640x640 1 book_flowerpot, 7.2ms
# image 17/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0059_JPEG.rf.4273c8a8049d786cb3dd9b4dda61942f.jpg: 640x640 3 book_flowerpots, 7.1ms
# image 18/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0060_JPEG.rf.9b5440594763872ffc738e742ab0586b.jpg: 640x640 3 book_flowerpots, 7.3ms
# image 19/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0068_JPEG.rf.d1a959db9db9b002325c9d02cc7ffcaa.jpg: 640x640 1 book_flowerpot, 1 book_monkey, 7.4ms
# image 20/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0076_JPEG.rf.8a737fcc8f2b85f9b9d4c727a4dc8b28.jpg: 640x640 2 book_flowerpots, 7.8ms
# image 21/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_flowerpot_0079_JPEG.rf.c7e3f8d5c73f73cfecfdc38de411d944.jpg: 640x640 2 book_flowerpots, 7.4ms
# image 22/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_0002_jpg.rf.9851317a05fca8210e59e172646f02e0.jpg: 640x640 1 book_monkey, 7.2ms
# image 23/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_0005_jpeg.rf.463cef3b669ab8166fb42f0a1662a22b.jpg: 640x640 1 book_monkey, 7.0ms
# image 24/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_0006_jpeg.rf.86d3c7c2134a943e206826808eb3eb1a.jpg: 640x640 1 book_monkey, 7.7ms
# image 25/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_0025_jpeg.rf.28ac740dfad07f6b30056213087c960e.jpg: 640x640 1 book_monkey, 14.1ms
# image 26/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_0067_jpeg.rf.6a787017253f9d0b80ff6ec027e9819a.jpg: 640x640 1 book_flowerpot, 13.1ms
# image 27/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_0135_jpg.rf.2d427c0e9cd9df47ee3f6c2c52daecc8.jpg: 640x640 1 book_monkey, 14.5ms
# image 28/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_0145_jpg.rf.34a575e33e101d12fd338b3f3a553310.jpg: 640x640 1 book_monkey, 16.5ms
# image 29/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_0177_JPEG.rf.d6c44e81eac5a9e43f17a3b17501ba7c.jpg: 640x640 3 book_monkeys, 14.1ms
# image 30/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_0214_JPEG.rf.c9800e19a46e49195be0713410fa2ebf.jpg: 640x640 3 book_monkeys, 11.0ms
# image 31/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_0240_JPEG.rf.add3183c347e10b4ffe86765002e30c5.jpg: 640x640 2 book_monkeys, 9.9ms
# image 32/96 /content/AI-Picture-Book-Object-Detection-6/test/images/book_monkey_
ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/picture_book_yolo11n_v6_test_predictions

# %%
# 저장된 예측 결과 이미지 일부 확인
from IPython.display import Image, display

result_images = sorted(glob.glob(f"runs/detect/{RUN_NAME}_test_predictions*/*.jpg"))

print("Detected images:", len(result_images))

for img_path in result_images[:10]:
    display(Image(filename=img_path))
# Out:
# Detected images: 96

# %%
# 백엔드 연동 시 필요한 모델 정보 정리
model_info = {
    "model_name": MODEL_NAME,
    "run_name": RUN_NAME,
    "dataset_version": ROBOFLOW_VERSION,
    "input": {
        "type": "image_or_webcam_frame",
        "image_size": IMG_SIZE,
    },
    "output": {
        "class_name": "detected object class",
        "confidence": "detection confidence score",
        "bbox": "[x1, y1, x2, y2]",
    },
    "classes": actual_classes,
    "best_model_path": best_model_path,
    "metrics": summary,
}

model_info_path = "results/yolo11n_v3_model_info.json"

with open(model_info_path, "w", encoding="utf-8") as f:
    json.dump(model_info, f, ensure_ascii=False, indent=2)

print("Saved model info:", model_info_path)
model_info
# Out:
# Saved model info: results/yolo11n_v3_model_info.json
# {'model_name': 'yolo11n.pt',
#  'run_name': 'picture_book_yolo11n_v6',
#  'dataset_version': 6,
#  'input': {'type': 'image_or_webcam_frame', 'image_size': 640},
#  'output': {'class_name': 'detected object class',
#   'confidence': 'detection confidence score',
#   'bbox': '[x1, y1, x2, y2]'},
#  'classes': ['book_flower',
#   'book_flowerpot',
#   'book_monkey',
#   'book_stone',
#   'braille',
#   'tactile_flower',
#   'tactile_flowerpot',
#   'tactile_monkey',
#   'tactile_stone',
#   'text'],
#  'best_model_path': '/content/runs/detect/runs/detect/picture_book_yolo11n_v6/weights/best.pt',
#  'metrics': {'model': 'yolo11n.pt',
#   'dataset_version': 6,
#   'precision': 0.834799931982832,
#   'recall': 0.7191307808985743,
#   'mAP@0.5': 0.7755055488769996,
#   'mAP@0.5:0.95': 0.5451876168317076,
#   'best_model_path': '/content/runs/detect/runs/detect/picture_book_yolo11n_v6/weights/best.pt'}}

# %% [markdown]
# ## YOLOv5s baseline vs YOLO11n v6 성능 비교
#
# | Model   | Dataset     | Precision | Recall | mAP@0.5 | mAP@0.5:0.95 | 비고                  |
# | ------- | ----------- | --------: | -----: | ------: | -----------: | ------------------- |
# | YOLOv5s | Roboflow v2 |     0.847 |  0.889 |   0.898 |        0.641 | 예인님 테스트 기준 baseline |
# | YOLO11n | Roboflow v6 |     0.835 |  0.719 |   0.776 |        0.545 | 전체 통합 데이터셋 기준       |
#
# ### 결과 해석
#
# YOLO11n은 Roboflow v6 전체 통합 데이터셋을 기준으로 학습 및 평가하였다.
# YOLOv5s baseline은 Roboflow v2 기준 결과이므로, 두 결과는 데이터셋 버전이 달라 직접적인 성능 우열 비교보다는 참고용 비교로 해석한다.
#
# YOLO11n v6의 test set 기준 전체 성능은 Precision 0.835, Recall 0.719, mAP@0.5 0.776, mAP@0.5:0.95 0.545로 확인되었다.
#
# ### 확인 사항
#
# * Roboflow v6 데이터셋에 10개 클래스가 모두 포함되어 있는지 확인함.
# * YOLO11n 학습 후 `best.pt` 파일 경로를 정리함.
# * test set 기준 Precision, Recall, mAP@0.5, mAP@0.5:0.95를 확인함.
# * 예측 결과 이미지를 저장하여 실제 탐지 품질을 확인할 예정임.
# * 백엔드 연동을 위해 class name, confidence, bbox 출력 형식을 정리할 예정임.
